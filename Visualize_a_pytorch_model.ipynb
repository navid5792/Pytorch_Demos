# %%
# !pip install torchviz
# Out:
# Collecting torchviz
#   Downloading https://files.pythonhosted.org/packages/8f/8e/a9630c7786b846d08b47714dd363a051f5e37b4ea0e534460d8cdfc1644b/torchviz-0.0.1.tar.gz (41kB)
#      |████████████████████████████████| 51kB 1.6MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchviz) (1.4.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from torchviz) (0.10.1)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.1-cp36-none-any.whl size=3523 sha256=d4e6dfdc8ed675588e1ffbe0aa0c6a41970bb02615dd718f3156597d22378998
#   Stored in directory: /root/.cache/pip/wheels/2a/c2/c5/b8b4d0f7992c735f6db5bfa3c5f354cf36502037ca2b585667
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.1

# %%
import torch
from torch import nn
from torchviz import make_dot, make_dot_from_trace

# %%
model = nn.Sequential()
model.add_module('W0', nn.Linear(8, 16))
model.add_module('tanh', nn.Tanh())
model.add_module('W1', nn.Linear(16, 1))

x = torch.randn(1,8)
print(model)
make_dot(model(x), params=dict(model.named_parameters()))
# Out:
# Sequential(
#   (W0): Linear(in_features=8, out_features=16, bias=True)
#   (tanh): Tanh()
#   (W1): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
class test(nn.Module):
  def __init__(self):
    super(test, self).__init__()
    self.layer1 = nn.Linear(8,16)
    self.layer2 = nn.Linear(16,16)
    self.layer3 = nn.Linear(16,1)
  def forward(self, x):
    a = self.layer1(x)
    b = self.layer2(a)
    y = self.layer3(b)
    return y

x = torch.randn(1,8)
model = test()
print(model)

make_dot(model(x), params=dict(model.named_parameters()))
# Out:
# test(
#   (layer1): Linear(in_features=8, out_features=16, bias=True)
#   (layer2): Linear(in_features=16, out_features=16, bias=True)
#   (layer3): Linear(in_features=16, out_features=1, bias=True)
# )
